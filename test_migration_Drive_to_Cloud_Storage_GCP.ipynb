# %%
from gcp_functions import migrate_drive_to_gcp

# %%
migrate_drive_to_gcp(folder_id="175eBYBMz4HppO7c6LihopQqS0eojr3Hb", 
                     bucket_name="test_documentai_process",
                     master_folder="new_inputs_doc")
# Out:
# credencials.json-drive-v3-(['https://www.googleapis.com/auth/drive'],)
# ['https://www.googleapis.com/auth/drive']
# drive service created successfully
# bank of america (1DqdyjcoH8vY1KINHXOsxnZvj45bcZv2t)
# Found file: eStmt_2021-03-31.pdf, 1OERDrOOiWjbhaqDkFko6ZhkaDT9QQUTc
# Found file: eStmt_2021-07-30.pdf, 1vuz8uZySSZ4J407GlbkXOEzpB46TlGvf
# Found file: eStmt_2021-04-30.pdf, 1FSixUCZWD-pxMVvyd5Mbp2tAxtqiISKg
# Found file: eStmt_2021-05-28.pdf, 10PSz5byarL_0R89tJTIjJyTmJtHzkSaa
# Found file: eStmt_2021-06-30.pdf, 1fTy0zGtYpeIolDioni9Ba2wylDEidath
# Found file: eStmt_2021-09-30.pdf, 1WuPuSKdgNq9cfhwykARESKQwMJM-Th9g
# Found file: eStmt_2021-08-31.pdf, 1o6JUo0xbOLtylBHUxhLuDHvYg2aAQMQi
# Found file: bank of america.pdf, 16HFY8EkIZjphXGvyENIKMPBEbH6mEhUb
# https://storage.googleapis.com/download/storage/v1/b/test_documentai_process/o/new_inputs_doc%2Fbank%20of%20america%2FeStmt_2021-03-31.pdf?generation=1671210306091912&alt=media
# ...
